# %% [markdown]
# <a href="https://colab.research.google.com/github/BaranikumarNagarajan/BaranikumarNagarajan/blob/main/Python_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exploratory Data Analysis/ Data Preprocessing
#
# Project Objective ==> Target Variable???
#
# Dataframe ==> 10 columns ==>
#
# Dataset ==>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-77712442-a529-4067-9fd4-669b3a228b8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-77712442-a529-4067-9fd4-669b3a228b8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#bytestream ==> io
import io
data = pd.read_csv(io.BytesIO(uploaded['train.csv']))

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
#columns ==> data types

data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# describe

data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#standard deviation

# median ==> centre value

#0     14                          512

# %%
data.describe(include=['object'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# mode ==> frequency of occurence is high

# %%
#categorical data ==> binary or multiple categories

new_gender = pd.Categorical(data.Sex).rename_categories([0,1])

# %%
new_gender
# Out:
# [1, 0, 0, 0, 1, ..., 1, 0, 0, 1, 1]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
data['gender'] = new_gender

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked gender
# 0      0         A/5 21171   7.2500   NaN        S      1
# 1      0          PC 17599  71.2833   C85        C      0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      0
# 3      0            113803  53.1000  C123        S      0
# ...

# %%
data['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
# List comprehension

new_cabin = data['Cabin'].astype(str)

# %%
m = np.array([i[0] for i in new_cabin])

# %%
m
# Out:
# array(['n', 'C', 'n', 'C', 'n', 'n', 'E', 'n', 'n', 'n', 'G', 'C', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'D', 'n', 'A', 'n', 'n',
#        'n', 'C', 'n', 'n', 'n', 'B', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n',
#        'D', 'n', 'B', 'C', 'n', 'n', 'n', 'n', 'n', 'B', 'C', 'n', 'n',
#        'n', 'F', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'F', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'C', 'n', 'n',
#        'n', 'E', 'n', 'n', 'n', 'A', 'D', 'n', 'n', 'n', 'n', 'D', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'C', 'n', 'n', 'n', 'n', 'n', 'n',
#        'n', 'B', 'n', 'n', 'n', 'n', 'E', 'D', 'n', 'n', 'n', 'F', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'D', 'C', 'n', 'B', 'n', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'F', 'n', 'n', 'C', 'n', 'n', 'n', 'n',
#        'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'E', 'n', 'n',
# ...

# %%
updated_cabin = pd.Categorical(m)

updated_cabin.describe()
# Out:
#             counts     freqs
# categories
# A               15  0.016835
# B               47  0.052750
# C               59  0.066218
# D               33  0.037037
# E               32  0.035915
# F               13  0.014590
# G                4  0.004489
# T                1  0.001122
# n              687  0.771044

# %%
# Missing value handling ==> 2/3 missing values ==> Remove Cabin column from Predictions
# Cabin ?

# %%
data['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# Handling Missing values:
#
# Replace null values with 0
#
# Replace null values with some central values like mean or median
#
# Impute values(ML algorithms)

# %%
new_age = np.where(data['Age'].isnull(),28,data['Age']) #median prefer

# %%
data.hist(column='Age',figsize=(3,3),bins=20)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
data['Age'] = new_age

# %%
data['Age'].describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data.hist(column='Age',figsize=(10,3),bins=10)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
#cabin,Age,Sex ==> Model build ==> 80% accuracy

#Mr,Mrs,Miss ==> Avg .age value

#Misiing value ==> Mr.==>

#0 ==> 80

# %%
#outliers ==> EDA

# box plot / Whiskers plot

data['Fare'].plot(kind='box',figsize=(4,4))
# Out:
# <Axes: >

# %%
data['Age'].plot(kind='box')
# Out:
# <Axes: >

# %%
# outliers remove
#outliers replace with mean or median

# %%
index = np.where(data['Fare'] == max(data['Fare']))


data.loc[index]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     gender
# 258      0
# 679      1
# 737      1

# %%
data['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
# Feature Engineering

# should i create new columns(variables)?

data['Family'] = data['SibSp'] + data['Parch']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
family_index = np.where(data['Family'] == max(data['Family']))

# %%
print(family_index)
# Out:
# (array([159, 180, 201, 324, 792, 846, 863]),)

# %%
data.iloc[family_index]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket   Fare Cabin Embarked gender  Family
# 159  28.0      8      2  CA. 2343  69.55   NaN        S      1      10
# 180  28.0      8      2  CA. 2343  69.55   NaN        S      0      10
# 201  28.0      8      2  CA. 2343  69.55   NaN        S      1      10
# ...

# %%
# missing data
# survived?

# %%
# Categorical data ==> Male,Female   ==> nominal ==> one-hot encoding technique/one of K encoding
                #  ==> Temp --> High,Med,low ==> ordinal --> High>Med>low ==>3,2,1

#pd.get_dummies

# categories ==>

# %%
df = pd.DataFrame({'Color':['Red','Green','Blue','Blue']})

# %%
df
# Out:
#    Color
# 0    Red
# 1  Green
# 2   Blue
# 3   Blue

# %%
sample_dummies = pd.get_dummies(df['Color'])

# %%
sample_dummies
# Out:
#    Blue  Green  Red
# 0     0      0    1
# 1     0      1    0
# 2     1      0    0
# 3     1      0    0

# %%
pd.concat([df,sample_dummies],axis=1)
# Out:
#    Color  Blue  Green  Red
# 0    Red     0      0    1
# 1  Green     0      1    0
# 2   Blue     1      0    0
# 3   Blue     1      0    0

# %%
# Machine Learning ==> Curse of Dimensionality ==> Model accuracy

# %%
pd.get_dummies(df['Color'],drop_first=True)  # columns/features/variables/Dimensions
# Out:
#    Green  Red
# 0      0    1
# 1      1    0
# 2      0    0
# 3      0    0

# %%
df2 = pd.DataFrame(
   {
       "A": [1.0,2.0],
           "B": pd.Timestamp("20130102"),
           "C": pd.Series(1, index=list(range(4)), dtype="float32"),
            "D": np.array([3] * 4, dtype="int32"),
           "E": pd.Categorical(["test", "train", "test", "train"]),
            "F": "foo",
       }
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-f199198fc812> in <cell line: 1>()
# ----> 1 df2 = pd.DataFrame(
#       2    {
#       3        "A": [1.0,2.0],
#       4            "B": pd.Timestamp("20130102"),
#       5            "C": pd.Series(1, index=list(range(4)), dtype="float32"),
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# ...

# %% [markdown]
# 1000 records ==> 25 records missing data ==> drop

# %%
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64
